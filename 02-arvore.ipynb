# %%
from sklearn import tree
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

import pandas

# %%
dataset = load_iris()

# %%
X = pandas.DataFrame(dataset['data'], columns= dataset['feature_names'])
y = pandas.Series(dataset['target'], name = 'target')

# %%
clf = tree.DecisionTreeClassifier()

# %%
clf = clf.fit(X, y)

# %%
tree.plot_tree(clf)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 tree.plot_tree(clf)
#
# File ~/Documents/Kvizinhos/venv/lib/python3.14/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/Documents/Kvizinhos/venv/lib/python3.14/site-packages/sklearn/tree/_export.py:220, in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rounded, precision, ax, fontsize)
#     205 check_is_fitted(decision_tree)
#     207 exporter = _MPLTreeExporter(
#     208     max_depth=max_depth,
#     209     feature_names=feature_names,
#    (...)    218     fontsize=fontsize,
#     219 )
# --> 220 return exporter.export(decision_tree, ax=ax)
#
# File ~/Documents/Kvizinhos/venv/lib/python3.14/site-packages/sklearn/tree/_export.py:658, in _MPLTreeExporter.export(self, decision_tree, ax)
#     657 def export(self, decision_tree, ax=None):
# --> 658     import matplotlib.pyplot as plt
#     659     from matplotlib.text import Annotation
#     661     if ax is None:
#
# ModuleNotFoundError: No module named 'matplotlib'
