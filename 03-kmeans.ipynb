# %%
from sklearn.datasets import load_iris
from sklearn.cluster import DBSCAN, KMeans

import pandas

# %%
datasets = load_iris()

# %%
X = pandas.DataFrame(datasets['data'], columns= datasets['feature_names'])
